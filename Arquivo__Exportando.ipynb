# %%
# Bibliotecas
import pandas as pd

# %%
# Importar dados de exemplo
tabela = pd.read_csv("https://aluno.analisemacro.com.br/download/46594/?tmstv=1675516396")
tabela
# Out:
#            data     pib
# 0    1996-01-01   99.55
# 1    1996-04-01  100.44
# 2    1996-07-01  104.38
# 3    1996-10-01  103.30
# 4    1997-01-01  104.32
# ..          ...     ...
# 100  2021-01-01  171.54
# 101  2021-04-01  171.17
# 102  2021-07-01  171.28
# 103  2021-10-01  172.41
# 104  2022-01-01  174.13
#
# [105 rows x 2 columns]

# %%
# Exportando dados
#CSV
tabela.to_csv("C:/Users/Mateus de Barros/OneDrive/Documentos/Diversos/Educação/Analise_Macro/Python/Scripts_Python/dados.csv", index = False)

# %%
# Excel
tabela.to_excel(excel_writer = "C:/Users/Mateus de Barros/OneDrive/Documentos/Diversos/Educação/Analise_Macro/Python/Scripts_Python/dados.xlsx", index = False )

# %%
# Stata
tabela.to_stata(path = "C:/Users/Mateus de Barros/OneDrive/Documentos/Diversos/Educação/Analise_Macro/Python/Scripts_Python/dados.dta", write_index=False)
