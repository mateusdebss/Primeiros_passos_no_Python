# %%
# Biblioteca
import pandas as pd

# %%
# Dados
# Impotação de CSV offline
tabela = pd.read_csv(filepath_or_buffer = "dados.csv")
tabela
# Out:
#            data     pib
# 0    1996-01-01   99.55
# 1    1996-04-01  100.44
# 2    1996-07-01  104.38
# 3    1996-10-01  103.30
# 4    1997-01-01  104.32
# ..          ...     ...
# 100  2021-01-01  171.54
# 101  2021-04-01  171.17
# 102  2021-07-01  171.28
# 103  2021-10-01  172.41
# 104  2022-01-01  174.13
#
# [105 rows x 2 columns]

# %%
# Impotação de CSV online
tabela = pd.read_csv(filepath_or_buffer = "https://analisemacro.com.br/download/39167/")
tabela
# Out:
#            data     pib
# 0    1996-01-01   99.55
# 1    1996-04-01  100.44
# 2    1996-07-01  104.38
# 3    1996-10-01  103.30
# 4    1997-01-01  104.32
# ..          ...     ...
# 100  2021-01-01  171.54
# 101  2021-04-01  171.17
# 102  2021-07-01  171.28
# 103  2021-10-01  172.41
# 104  2022-01-01  174.13
#
# [105 rows x 2 columns]

# %%
# Impotação de CSV com separador
tabela = pd.read_csv(filepath_or_buffer = "dados_pv.csv", sep = ";", decimal = ",")
tabela
# Out:
#            data     pib
# 0    1996-01-01   99.55
# 1    1996-04-01  100.44
# 2    1996-07-01  104.38
# 3    1996-10-01  103.30
# 4    1997-01-01  104.32
# ..          ...     ...
# 100  2021-01-01  171.54
# 101  2021-04-01  171.17
# 102  2021-07-01  171.28
# 103  2021-10-01  172.41
# 104  2022-01-01  174.13
#
# [105 rows x 2 columns]

# %%
# Impotação de CSV com codificação diferente do padrão
tabela = pd.read_csv(
    filepath_or_buffer = "https://aluno.analisemacro.com.br/download/45589/?tmstv=1672743605",
    sep = ";",
    encoding = "latin_1"
)
tabela
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0       01/11/2022   16:05:25         2022                2
# 1       01/11/2022   16:05:25         2022                2
# 2       01/11/2022   16:05:25         2022                2
# 3       01/11/2022   16:05:25         2022                2
# 4       01/11/2022   16:05:25         2022                2
# ...            ...        ...          ...              ...
# 277660  01/11/2022   16:05:25         2022                2
# 277661  01/11/2022   16:05:25         2022                2
# 277662  01/11/2022   16:05:25         2022                2
# 277663  01/11/2022   16:05:25         2022                2
# 277664  01/11/2022   16:05:25         2022                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO  \
# 0       ELEIÇÃO ORDINÁRIA         1         546
# 1       ELEIÇÃO ORDINÁRIA         1         546
# 2       ELEIÇÃO ORDINÁRIA         1         546
# ...
