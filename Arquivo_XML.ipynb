# %%
# Bibliotecas
import pandas as pd

# %%
# Importar arquivos XML
# Online
pd.read_xml(path_or_buffer = "https://raw.githubusercontent.com/schoulten/credit/main/dados.xml")
# Out:
#          V                          MC                 MN  \
# 0    Valor  Unidade de Medida (Código)  Unidade de Medida
# 1     0.21                           2                  %
# 2     0.25                           2                  %
# 3     0.07                           2                  %
# 4    -0.31                           2                  %
# ..     ...                         ...                ...
# 392  -0.90                           2                  %
# 393  -0.46                           2                  %
# 394   0.76                           2                  %
# 395   0.42                           2                  %
# 396   0.56                           2                  %
#
#                              NC                    NN  \
# 0    Nível Territorial (Código)     Nível Territorial
# 1                             1                Brasil
# 2                             1                Brasil
# ...

# %%
# Offline
pd.read_xml(path_or_buffer = "C:/Users/Mateus de Barros/OneDrive/Documentos/Diversos/Educação/Analise_Macro/Python/Material_Aula/pad21/dados/dados.xml")
# Out:
#          V                          MC                 MN  \
# 0    Valor  Unidade de Medida (Código)  Unidade de Medida
# 1     0.21                           2                  %
# 2     0.25                           2                  %
# 3     0.07                           2                  %
# 4    -0.31                           2                  %
# ..     ...                         ...                ...
# 392  -0.90                           2                  %
# 393  -0.46                           2                  %
# 394   0.76                           2                  %
# 395   0.42                           2                  %
# 396   0.56                           2                  %
#
#                              NC                    NN  \
# 0    Nível Territorial (Código)     Nível Territorial
# 1                             1                Brasil
# 2                             1                Brasil
# ...
